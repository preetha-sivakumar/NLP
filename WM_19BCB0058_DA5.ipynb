# %%
# QUESTION 1-PAGERANK
import networkx as nx
import pylab as plt

D = nx.DiGraph()

D.add_weighted_edges_from([('A','B',1),('A','C',1),('C','A',1),('A','D',1),('D','B',1),('D','C',1),('B','C',1)])
print(nx.pagerank(D))
nx.draw(D,with_labels =True)
plt.show()
# Out:
# {'A': 0.3328665861942923, 'B': 0.1878321232402152, 'C': 0.34748890126006193, 'D': 0.13181238930543057}

# %%
D = nx.DiGraph()

D.add_weighted_edges_from([('A','B',12),('A','C',2),('C','A',1),('A','D',1),('D','B',2),('D','C',1),('B','C',10)])
print(nx.pagerank(D))
nx.draw(D,with_labels =True)
plt.show()
# Out:
# {'A': 0.3218303822549087, 'B': 0.28792771968283815, 'C': 0.3345049454259066, 'D': 0.05573695263634658}

# %%
print("PREETHA SIVAKUMAR 19BCB0058")
# Out:
# PREETHA SIVAKUMAR 19BCB0058

# %%
# QUESTION 2- hits algorithm
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph()
G.add_edges_from([('A', 'D'), ('B', 'C'), ('B', 'E'), ('C', 'A'),
 ('D', 'C'), ('E', 'D'), ('E', 'B'), ('E', 'F'),
 ('E', 'C'), ('F', 'C'), ('F', 'H'), ('G', 'A'),
 ('G', 'C'), ('H', 'A')])

# %%
plt.figure(figsize =(10, 10))
nx.draw_networkx(G, with_labels = True)

# %%
hubs, authorities = nx.hits(G, max_iter = 50, normalized = True)
print("Hub Scores: ", hubs)
print("Authority Scores: ", authorities)
# Out:
# Hub Scores:  {'A': 0.046425404032199934, 'D': 0.13366037526115382, 'B': 0.15763599442967322, 'C': 0.037389132246426544, 'E': 0.2588144598468664, 'F': 0.15763599442967322, 'H': 0.037389132246426544, 'G': 0.17104950750758036}
# Authority Scores:  {'A': 0.10864044011724347, 'D': 0.13489685434357995, 'B': 0.11437974073336445, 'C': 0.38837280038761807, 'E': 0.06966521184241478, 'F': 0.11437974073336445, 'H': 0.06966521184241478, 'G': 0.0}

# %%
print("PREETHA SIVAKUMAR 19BCB0058")
# Out:
# PREETHA SIVAKUMAR 19BCB0058
